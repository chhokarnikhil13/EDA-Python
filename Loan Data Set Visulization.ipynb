# %%
# Pandas and numpy for data manipulation
import numpy as np
import pandas as pd 
# Matplotlib visualization
import matplotlib.pyplot as plt
# Seaborn for visualization
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\chhok\Downloads\credit_tes.csv")

# %%
# Display dataset
df
# Out:
#                                Customer ID Loan Amount Categories  \
# 0     5e471d4f-8b63-4ec2-9864-faa9dc2cfd57           100k to 500k
# 1     b986d763-6fd4-4929-a43d-9551d0f4e76f           100k to 500k
# 2     f69adadf-c2bf-46eb-b9cb-088a92430d28           100k to 500k
# 3     be726c2f-ffd4-423e-bbf9-af999010ff4e           100k to 500k
# 4     5b3a9d7b-cd9a-403b-8460-a73b2cf8e840           100k to 500k
# ...                                    ...                    ...
# 9995  504e10f5-4d32-4679-aec6-4d0100659a27           100k to 500k
# 9996  a78e6f34-9f66-45fb-bbf6-3d03b9a24497           100k to 500k
# 9997  6e43a9fd-5c79-402a-823f-ddbc7d267333           100k to 500k
# 9998  3378cc3c-d0e7-4619-a5ef-d1b050ff0d5e            50k to 100k
# 9999  cc94e25e-1060-4465-b603-194e122f0239           100k to 500k
#
#       Current Loan Amount        Term  Credit Score  Annual Income  \
# 0                  322124  Short Term         751.0      1335301.0
# 1                  315106  Short Term         750.0      1022903.0
# 2                  216128  Short Term         750.0       858610.0
# 3                  128920  Short Term         750.0       872195.0
# 4                  111056  Short Term         749.0       623371.0
# ...                   ...         ...           ...            ...
# 9995               312950   Long Term           NaN            NaN
# 9996               111716  Short Term           NaN            NaN
# 9997               134860  Short Term           NaN            NaN
# 9998                66308  Short Term           NaN            NaN
# 9999               223212   Long Term           NaN            NaN
#
#       Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0                     10.0  Home Mortgage           Buy a Car      20585.93
# 1                      3.0           Rent  Debt Consolidation      22248.24
# 2                     10.0  Home Mortgage  Debt Consolidation      11090.49
# 3                      4.0  Home Mortgage  Debt Consolidation       9594.05
# 4                      3.0       Own Home               other       8477.80
# ...                    ...            ...                 ...           ...
# 9995                   5.0  Home Mortgage   Home Improvements       4690.15
# 9996                   3.0  Home Mortgage               Other        383.61
# 9997                   6.0  Home Mortgage  Debt Consolidation      20856.49
# 9998                   1.0           Rent               Other       4335.23
# 9999                   NaN           Rent  Debt Consolidation       4354.42
#
#       Years of Credit History  Months since last delinquent  \
# 0                        15.6                          21.0
# 1                        19.9                           NaN
# 2                        27.4                           NaN
# 3                        15.1                           NaN
# 4                        13.0                           NaN
# ...                       ...                           ...
# 9995                      7.8                           NaN
# 9996                     15.0                          66.0
# 9997                     22.3                          60.0
# 9998                     18.5                          37.0
# 9999                     27.2                           NaN
#
#       Number of Open Accounts  Number of Credit Problems  \
# 0                          18                          0
# 1                           5                          0
# 2                           9                          0
# 3                           8                          0
# 4                          12                          0
# ...                       ...                        ...
# 9995                        8                          0
# 9996                        6                          0
# 9997                       12                          1
# 9998                        7                          0
# 9999                        8                          1
#
#       Current Credit Balance  Maximum Open Credit  Bankruptcies  Tax Liens
# 0                     156636               902352           0.0        0.0
# 1                     871739              2258124           0.0        0.0
# 2                     340214               624316           0.0        0.0
# 3                      62396               880990           0.0        0.0
# 4                       8493                35508           0.0        0.0
# ...                      ...                  ...           ...        ...
# 9995                  183654               354442           0.0        0.0
# 9996                   10013               141416           0.0        0.0
# 9997                  141854               521422           1.0        0.0
# 9998                   25194                97240           0.0        0.0
# 9999                   99636               568370           1.0        0.0
#
# [10000 rows x 18 columns]

# %%
# checking data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer ID                   10000 non-null  object
#  1   Loan Amount Categories        10000 non-null  object
#  2   Current Loan Amount           10000 non-null  int64
#  3   Term                          10000 non-null  object
#  4   Credit Score                  8019 non-null   float64
#  5   Annual Income                 8019 non-null   float64
#  6   Years in current job          9573 non-null   float64
#  7   Home Ownership                10000 non-null  object
#  8   Purpose                       10000 non-null  object
#  9   Monthly Debt                  10000 non-null  float64
#  10  Years of Credit History       10000 non-null  float64
#  11  Months since last delinquent  4694 non-null   float64
#  12  Number of Open Accounts       10000 non-null  int64
#  13  Number of Credit Problems     10000 non-null  int64
#  14  Current Credit Balance        10000 non-null  int64
#  15  Maximum Open Credit           10000 non-null  int64
#  16  Bankruptcies                  9978 non-null   float64
#  17  Tax Liens                     9999 non-null   float64
# dtypes: float64(8), int64(5), object(5)
# memory usage: 1.4+ MB

# %%
## Data Cleaning

# %%
df["Months since last delinquent"].fillna("0", inplace = True)
df["Bankruptcies"].fillna("0", inplace = True)
df["Tax Liens"].fillna("0", inplace = True)
df = df.dropna(how='any',axis=0)

# %%
#checking
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7677 entries, 0 to 8018
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer ID                   7677 non-null   object
#  1   Loan Amount Categories        7677 non-null   object
#  2   Current Loan Amount           7677 non-null   int64
#  3   Term                          7677 non-null   object
#  4   Credit Score                  7677 non-null   float64
#  5   Annual Income                 7677 non-null   float64
#  6   Years in current job          7677 non-null   float64
#  7   Home Ownership                7677 non-null   object
#  8   Purpose                       7677 non-null   object
#  9   Monthly Debt                  7677 non-null   float64
#  10  Years of Credit History       7677 non-null   float64
#  11  Months since last delinquent  7677 non-null   object
#  12  Number of Open Accounts       7677 non-null   int64
#  13  Number of Credit Problems     7677 non-null   int64
#  14  Current Credit Balance        7677 non-null   int64
#  15  Maximum Open Credit           7677 non-null   int64
#  16  Bankruptcies                  7677 non-null   object
#  17  Tax Liens                     7677 non-null   object
# dtypes: float64(5), int64(5), object(8)
# memory usage: 1.1+ MB

# %%
# Statistics for each numeric column
df.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income  Years in current job  \
# count         7.677000e+03   7677.000000   7.677000e+03           7677.000000
# mean          1.442915e+07    716.573792   1.386661e+06              5.955842
# std           3.475614e+07     28.251650   8.736151e+05              3.492306
# min           1.947000e+04    585.000000   8.109200e+04              1.000000
# 25%           1.875940e+05    704.000000   8.606430e+05              3.000000
# 50%           3.254460e+05    723.000000   1.193143e+06              6.000000
# 75%           5.477560e+05    739.000000   1.680778e+06             10.000000
# max           1.000000e+08    751.000000   1.781535e+07             10.000000
#
#         Monthly Debt  Years of Credit History  Number of Open Accounts  \
# count    7677.000000              7677.000000              7677.000000
# mean    18650.025618                17.971643                11.125440
# std     12256.098661                 6.709173                 5.034252
# min         0.000000                 3.800000                 1.000000
# 25%     10393.380000                13.500000                 8.000000
# 50%     16284.140000                16.900000                10.000000
# 75%     24198.590000                21.500000                14.000000
# max    143526.570000                52.500000                55.000000
#
#        Number of Credit Problems  Current Credit Balance  Maximum Open Credit
# count                7677.000000            7.677000e+03         7.677000e+03
# mean                    0.159047            2.925320e+05         6.582663e+05
# std                     0.492360            3.839128e+05         9.987079e+05
# min                     0.000000            0.000000e+00         0.000000e+00
# 25%                     0.000000            1.105040e+05         2.723160e+05
# 50%                     0.000000            2.111850e+05         4.624840e+05
# 75%                     0.000000            3.684860e+05         7.849600e+05
# max                    10.000000            1.623744e+07         3.752742e+07

# %%
df
# Out:
#                                Customer ID Loan Amount Categories  \
# 0     5e471d4f-8b63-4ec2-9864-faa9dc2cfd57           100k to 500k
# 1     b986d763-6fd4-4929-a43d-9551d0f4e76f           100k to 500k
# 2     f69adadf-c2bf-46eb-b9cb-088a92430d28           100k to 500k
# 3     be726c2f-ffd4-423e-bbf9-af999010ff4e           100k to 500k
# 4     5b3a9d7b-cd9a-403b-8460-a73b2cf8e840           100k to 500k
# ...                                    ...                    ...
# 8014  e1c87c2d-e07d-400d-aabc-a05e5a29b03d           100k to 500k
# 8015  bdb62c52-116c-4ba1-bc81-3b31d9f5e02e           100k to 500k
# 8016  badbb5dc-9aef-4f7b-8d66-5233a296a5e7           100k to 500k
# 8017  c0663df4-25a3-4216-8fc9-6ec612ce7790           100k to 500k
# 8018  af3c1ec1-b244-42e2-9a7c-b12193e2a85b           100k to 500k
#
#       Current Loan Amount        Term  Credit Score  Annual Income  \
# 0                  322124  Short Term         751.0      1335301.0
# 1                  315106  Short Term         750.0      1022903.0
# 2                  216128  Short Term         750.0       858610.0
# 3                  128920  Short Term         750.0       872195.0
# 4                  111056  Short Term         749.0       623371.0
# ...                   ...         ...           ...            ...
# 8014               313038   Long Term         594.0      1408052.0
# 8015               350284   Long Term         588.0      3937465.0
# 8016               265892   Long Term         587.0      4975568.0
# 8017               272756   Long Term         586.0       936605.0
# 8018               332442   Long Term         585.0       960184.0
#
#       Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0                     10.0  Home Mortgage           Buy a Car      20585.93
# 1                      3.0           Rent  Debt Consolidation      22248.24
# 2                     10.0  Home Mortgage  Debt Consolidation      11090.49
# 3                      4.0  Home Mortgage  Debt Consolidation       9594.05
# 4                      3.0       Own Home               other       8477.80
# ...                    ...            ...                 ...           ...
# 8014                  10.0  Home Mortgage  Debt Consolidation      21707.31
# 8015                   4.0           Rent  Debt Consolidation      63655.51
# 8016                   2.0           Rent  Debt Consolidation      34207.03
# 8017                   1.0  Home Mortgage  Debt Consolidation      19902.88
# 8018                   8.0  Home Mortgage  Debt Consolidation      18643.56
#
#       Years of Credit History Months since last delinquent  \
# 0                        15.6                         21.0
# 1                        19.9                            0
# 2                        27.4                            0
# 3                        15.1                            0
# 4                        13.0                            0
# ...                       ...                          ...
# 8014                     21.6                         40.0
# 8015                     26.7                         19.0
# 8016                     14.3                          5.0
# 8017                     12.3                         32.0
# 8018                     16.0                            0
#
#       Number of Open Accounts  Number of Credit Problems  \
# 0                          18                          0
# 1                           5                          0
# 2                           9                          0
# 3                           8                          0
# 4                          12                          0
# ...                       ...                        ...
# 8014                       18                          0
# 8015                       25                          0
# 8016                        8                          0
# 8017                       19                          0
# 8018                       15                          0
#
#       Current Credit Balance  Maximum Open Credit Bankruptcies Tax Liens
# 0                     156636               902352          0.0       0.0
# 1                     871739              2258124          0.0       0.0
# 2                     340214               624316          0.0       0.0
# 3                      62396               880990          0.0       0.0
# 4                       8493                35508          0.0       0.0
# ...                      ...                  ...          ...       ...
# 8014                  562514               765380          0.0       0.0
# 8015                  314374               756800          0.0       0.0
# 8016                   56810                67606          0.0       0.0
# 8017                  134957               264418          0.0       0.0
# 8018                  333697               472934          0.0       0.0
#
# [7677 rows x 18 columns]

# %%
plt.figure(figsize=(22,11))
sns.countplot(x='Purpose',data=df)
plt.title("Purpose of taking loan",fontdict={'fontsize':20})
plt.show()

# %%
plt.figure(figsize=(8,8))
tbt = ["Stort Term", "Long Term"]
plt.pie(df.Term.value_counts(), labels = tbt, startangle = 100, explode=[0,0.09], shadow = True)
plt.title('Time Period of Taking Loan',fontdict={'fontsize':20})
plt.show()

## Short term vs long term distribution

# %%
#creating variable for loan amount range
str = df["Loan Amount Categories"].value_counts()
lbr = ["100k to 500k", "500k to 1M", "above 1M", "50k to 100k", "0 to 50k"]
plt.figure(figsize=(8,8))
plt.pie(str, labels = lbr, startangle = 100)
plt.title("Loan Amount", fontdict={'fontsize':20}) 
plt.show() 


###  -- The distribution of loan amount as per amount

# %%
plt.figure(figsize=(15,7))

x = df["Annual Income"]
plt.hist(x, bins=1000)
plt.xlabel("Annual Income") 
plt.ylabel("Count") 
plt.title("Income of people taking loans", fontdict={'fontsize':20}) 
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='Home Ownership',data=df)
plt.title("Home Ownership",fontdict={'fontsize':20})
plt.show()

# %%
plt.figure(figsize=(15,7))

x = df["Years of Credit History"]
plt.hist(x, bins=600)
plt.xlabel("Years of Credit History") 
plt.ylabel("Count") 
plt.title("Credit History of People", fontdict={'fontsize':20}) 
plt.show()

# %%
plt.figure(figsize=(15,7))

x = df["Number of Open Accounts"]
plt.hist(x, bins=200)
plt.xlabel("Number of Open Accounts") 
plt.ylabel("Count") 
plt.title("No of accounts open per person", fontdict={'fontsize':20}) 
plt.show()

# %%
plt.figure(figsize=(15,7))

x = df["Credit Score"]
plt.hist(x, bins=600)
plt.xlabel("Credit Score") 
plt.ylabel("Count") 
plt.title("Credit Score of People", fontdict={'fontsize':20}) 
plt.show()

# %%
plt.figure(figsize=(15,7))

x = df["Monthly Debt"]
plt.hist(x, bins=1000)
plt.xlabel("Monthly Debt") 
plt.ylabel("Count") 
plt.title("Monthly Debt Repayment", fontdict={'fontsize':20}) 
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='Years in current job',data=df)
plt.title('Job Status of people',fontdict={'fontsize':20})
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.countplot(x='Number of Credit Problems',data=df)
plt.title('Credit Problems',fontdict={'fontsize':20})
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7677 entries, 0 to 8018
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer ID                   7677 non-null   object
#  1   Loan Amount Categories        7677 non-null   object
#  2   Current Loan Amount           7677 non-null   int64
#  3   Term                          7677 non-null   object
#  4   Credit Score                  7677 non-null   float64
#  5   Annual Income                 7677 non-null   float64
#  6   Years in current job          7677 non-null   float64
#  7   Home Ownership                7677 non-null   object
#  8   Purpose                       7677 non-null   object
#  9   Monthly Debt                  7677 non-null   float64
#  10  Years of Credit History       7677 non-null   float64
#  11  Months since last delinquent  7677 non-null   object
#  12  Number of Open Accounts       7677 non-null   int64
#  13  Number of Credit Problems     7677 non-null   int64
#  14  Current Credit Balance        7677 non-null   int64
#  15  Maximum Open Credit           7677 non-null   int64
#  16  Bankruptcies                  7677 non-null   object
#  17  Tax Liens                     7677 non-null   object
# dtypes: float64(5), int64(5), object(8)
# memory usage: 1.4+ MB

# %%
df["Bankruptcies"] = df["Bankruptcies"].astype(int).astype(float)
# Out:
# <ipython-input-371-c8dd4ec31b50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Bankruptcies"] = df["Bankruptcies"].astype(int).astype(float)

# %%
sns.pairplot(df)
